# %%
pip install tensorflow streamlit opencv-python matplotlib pillow
# Out:
# Requirement already satisfied: tensorflow in c:\users\vyvid\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: streamlit in c:\users\vyvid\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: opencv-python in c:\users\vyvid\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\vyvid\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: pillow in c:\users\vyvid\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: jinja2 in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vyvid\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: colorama in c:\users\vyvid\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: namex in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vyvid\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vyvid\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# Load images from folders
datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)

train_data = datagen.flow_from_directory(
    'car_damage_dataset',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    'car_damage_dataset',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)

# Load a pre-trained model
base_model = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze base model for fast training
for layer in base_model.layers:
    layer.trainable = False

# Compile and train
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_data, validation_data=val_data, epochs=5)

# Save model
model.save("car_damage_model.h5")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 # Load images from folders
#      12 datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)
# ---> 14 train_data = datagen.flow_from_directory(
#      15     'car_damage_dataset',
#      16     target_size=(224, 224),
#      17     batch_size=16,
#      18     class_mode='categorical',
#      19     subset='training'
#      20 )
#      22 val_data = datagen.flow_from_directory(
#      23     'car_damage_dataset',
#      24     target_size=(224, 224),
#    (...)
#      27     subset='validation'
#      28 )
#      30 # Load a pre-trained model
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1138, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1120 def flow_from_directory(
#    1121     self,
#    1122     directory,
#    (...)
#    1136     keep_aspect_ratio=False,
#    1137 ):
# -> 1138     return DirectoryIterator(
#    1139         directory,
#    1140         self,
#    1141         target_size=target_size,
#    1142         color_mode=color_mode,
#    1143         keep_aspect_ratio=keep_aspect_ratio,
#    1144         classes=classes,
#    1145         class_mode=class_mode,
#    1146         data_format=self.data_format,
#    1147         batch_size=batch_size,
#    1148         shuffle=shuffle,
#    1149         seed=seed,
#    1150         save_to_dir=save_to_dir,
#    1151         save_prefix=save_prefix,
#    1152         save_format=save_format,
#    1153         follow_links=follow_links,
#    1154         subset=subset,
#    1155         interpolation=interpolation,
#    1156         dtype=self.dtype,
#    1157     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:453, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     451 if not classes:
#     452     classes = []
# --> 453     for subdir in sorted(os.listdir(directory)):
#     454         if os.path.isdir(os.path.join(directory, subdir)):
#     455             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'car_damage_dataset'

# %%
# Step 1: Import libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# Step 2: Load and preprocess images
datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)

train_data = datagen.flow_from_directory(
    'car_damage_dataset',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    'car_damage_dataset',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)

# Step 3: Build the model
base_model = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze base model layers
for layer in base_model.layers:
    layer.trainable = False

# Step 4: Compile and train
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_data, validation_data=val_data, epochs=5)

# Step 5: Save the model
model.save("car_damage_model.h5")
print("✅ Model trained and saved as car_damage_model.h5")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 15
#      12 # Step 2: Load and preprocess images
#      13 datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)
# ---> 15 train_data = datagen.flow_from_directory(
#      16     'car_damage_dataset',
#      17     target_size=(224, 224),
#      18     batch_size=16,
#      19     class_mode='categorical',
#      20     subset='training'
#      21 )
#      23 val_data = datagen.flow_from_directory(
#      24     'car_damage_dataset',
#      25     target_size=(224, 224),
#    (...)
#      28     subset='validation'
#      29 )
#      31 # Step 3: Build the model
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1138, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1120 def flow_from_directory(
#    1121     self,
#    1122     directory,
#    (...)
#    1136     keep_aspect_ratio=False,
#    1137 ):
# -> 1138     return DirectoryIterator(
#    1139         directory,
#    1140         self,
#    1141         target_size=target_size,
#    1142         color_mode=color_mode,
#    1143         keep_aspect_ratio=keep_aspect_ratio,
#    1144         classes=classes,
#    1145         class_mode=class_mode,
#    1146         data_format=self.data_format,
#    1147         batch_size=batch_size,
#    1148         shuffle=shuffle,
#    1149         seed=seed,
#    1150         save_to_dir=save_to_dir,
#    1151         save_prefix=save_prefix,
#    1152         save_format=save_format,
#    1153         follow_links=follow_links,
#    1154         subset=subset,
#    1155         interpolation=interpolation,
#    1156         dtype=self.dtype,
#    1157     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:453, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     451 if not classes:
#     452     classes = []
# --> 453     for subdir in sorted(os.listdir(directory)):
#     454         if os.path.isdir(os.path.join(directory, subdir)):
#     455             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'car_damage_dataset'

# %%
model_car_damage.h5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_car_damage.h5
#
# NameError: name 'model_car_damage' is not defined

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
pip install opencv-python pillow streamlit
# Out:
#   Cell In[1], line 1
#     pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install opencv-python pillow streamlit
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: filelock in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (4.11.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\vyvid\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in c:\users\vyvid\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp312-cp312-win_amd64.whl (215.1 MB)
#    ---------------------------------------- 0.0/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/215.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/215.1 MB 508.0 kB/s eta 0:07:03
#    ---------------------------------------- 0.5/215.1 MB 508.0 kB/s eta 0:07:03
#    ---------------------------------------- 0.8/215.1 MB 599.2 kB/s eta 0:05:58
#    ---------------------------------------- 0.8/215.1 MB 599.2 kB/s eta 0:05:58
#    ---------------------------------------- 0.8/215.1 MB 599.2 kB/s eta 0:05:58
#    ---------------------------------------- 0.8/215.1 MB 599.2 kB/s eta 0:05:58
#    ---------------------------------------- 1.0/215.1 MB 474.9 kB/s eta 0:07:31
#    ---------------------------------------- 1.3/215.1 MB 532.5 kB/s eta 0:06:42
1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  213.4/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  213.4/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  214.4/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  215.0/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  215.0/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  215.0/215.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 215.1/215.1 MB 3.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 5.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.5 MB 5.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.5 MB 5.6 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.5 MB 1.0 MB/s eta 0:00:02
#    ------------------------- -------------- 1.6/2.5 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.5 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.5 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.3 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 3.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.2 MB 3.9 MB/s eta 0:00:02
#    -------- ------------------------------- 1.3/6.2 MB 3.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.6/6.2 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.1/6.2 MB 2.3 MB/s eta 0:00:02
#    ------------- -------------------------- 2.1/6.2 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.2 MB 2.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.2 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: sympy, torch, torchvision, torchaudio
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.13.3 torch-2.7.0+cpu torchaudio-2.7.0+cpu torchvision-0.22.0+cpu
# Requirement already satisfied: opencv-python in c:\users\vyvid\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: pillow in c:\users\vyvid\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: streamlit in c:\users\vyvid\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\vyvid\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\vyvid\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\vyvid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\vyvid\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vyvid\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vyvid\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vyvid\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\vyvid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\vyvid\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
# !pip install tensorflow matplotlib numpy opencv-python
# Out:
# Requirement already satisfied: tensorflow in c:\users\vyvid\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: matplotlib in c:\users\vyvid\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\vyvid\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: opencv-python in c:\users\vyvid\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vyvid\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vyvid\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
def load_and_preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224))  # MobileNetV2 input size
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)
    return img_array

image_path = "car.jpg"  # Replace with your image
image = load_and_preprocess_image(image_path)

# Show the image
plt.imshow(load_img(image_path))
plt.axis('off')
plt.title("Input Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       6     return img_array
#       8 image_path = "car.jpg"  # Replace with your image
# ----> 9 image = load_and_preprocess_image(image_path)
#      11 # Show the image
#      12 plt.imshow(load_img(image_path))
#
# Cell In[5], line 2, in load_and_preprocess_image(image_path)
#       1 def load_and_preprocess_image(image_path):
# ----> 2     img = load_img(image_path, target_size=(224, 224))  # MobileNetV2 input size
#       3     img_array = img_to_array(img)
#       4     img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'car.jpg'

# %%
from IPython.display import display
from ipywidgets import FileUpload

upload = FileUpload(accept='image/*', multiple=False)
display(upload)
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')

# %%
pip install tensorflow opencv-python numpy matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\vyvid\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: opencv-python in c:\users\vyvid\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\vyvid\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\vyvid\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyvid\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vyvid\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\vyvid\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyvid\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vyvid\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyvid\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vyvid\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

# Simulated model prediction
def simulate_damage_prediction(frame):
    # Preprocess the frame
    resized = cv2.resize(frame, (224, 224))
    image = img_to_array(resized)
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)

    # Fake prediction (replace with model.predict later)
    prediction = np.random.rand()
    label = "Damaged" if prediction > 0.5 else "Not Damaged"
    color = (0, 0, 255) if label == "Damaged" else (0, 255, 0)
    
    return label, color

# %%
def run_webcam_detection():
    cap = cv2.VideoCapture(0)  # Open the webcam

    if not cap.isOpened():
        print("Error: Webcam not accessible.")
        return

    print("Press 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Simulated prediction
        label, color = simulate_damage_prediction(frame)

        # Display prediction
        cv2.putText(frame, f"Prediction: {label}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
        cv2.imshow("Car Damage Detection", frame)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

run_webcam_detection()
# Out:
# Press 'q' to quit.

# %%
def run_webcam_detection():
    cap = cv2.VideoCapture(0)  # Open the webcam

    if not cap.isOpened():
        print("Error: Webcam not accessible.")
        return

    print("Press 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Simulated prediction
        label, color = simulate_damage_prediction(frame)

        # Display prediction
        cv2.putText(frame, f"Prediction: {label}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
        cv2.imshow("Car Damage Detection", frame)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

run_webcam_detection()
# Out:
# Press 'q' to quit.

# %%
import cv2
cap = cv2.VideoCapture(0)

ret, frame = cap.read()
cap.release()

# Display the captured image
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Captured Frame")
plt.show()

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

def simulate_damage_prediction(frame):
    resized = cv2.resize(frame, (224, 224))
    image = img_to_array(resized)
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)

    confidence = np.random.rand()
    label = "Damaged" if confidence > 0.5 else "Not Damaged"
    color = (0, 0, 255) if label == "Damaged" else (0, 255, 0)
    return label, color, confidence

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output

def run_webcam_detection_jupyter():
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("❌ Error: Cannot access webcam.")
        return

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("⚠️ Failed to read frame.")
                break

            frame = cv2.flip(frame, 1)  # Mirror view
            label, color, conf = simulate_damage_prediction(frame)

            # Draw label on frame
            text = f"{label} ({conf:.2f})"
            cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
            cv2.rectangle(frame, (5, 5), (frame.shape[1]-5, frame.shape[0]-5), color, 2)

            # Convert BGR to RGB for display
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            # Display in notebook
            clear_output(wait=True)
            plt.imshow(rgb_frame)
            plt.axis('off')
            plt.title("Car Damage Detection (Press Kernel Stop to End)")
            plt.show()

    except KeyboardInterrupt:
        print("⏹️ Stopped by user.")

    cap.release()
    cv2.destroyAllWindows()

run_webcam_detection_jupyter()
# Out:
# ⏹️ Stopped by user.

# %%
import cv2
import numpy as np
import streamlit as st
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from IPython.display import display, Image

# Simulated Damage Prediction
def simulate_damage_prediction(frame):
    resized = cv2.resize(frame, (224, 224))
    image = img_to_array(resized)
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)

    confidence = np.random.rand()
    label = "Damaged" if confidence > 0.5 else "Not Damaged"
    color = (255, 0, 0) if label == "Damaged" else (0, 255, 0)
    return label, confidence, color

# Streamlit integration to show webcam feed in a notebook
def streamlit_webcam():
    st.title("🚗 Car Damage Detection via Webcam")

    run = st.checkbox('Start Webcam')

    if run:
        cap = cv2.VideoCapture(0)

        # Loop until user stops webcam
        while True:
            ret, frame = cap.read()
            if not ret:
                st.error("❌ Failed to read from webcam.")
                break

            frame = cv2.flip(frame, 1)  # Mirror the frame
            label, confidence, color = simulate_damage_prediction(frame)
            cv2.putText(frame, f'{label} ({confidence:.2f})', (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

            # Display frame in Streamlit
            st.image(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        cap.release()
    else:
        st.warning('Webcam is off.')
